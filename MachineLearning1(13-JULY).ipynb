# %% [raw]
# MACHINE LEARNING ->
# ARTIFICIAL INTELLIGENCE : ITELLIGENCE WHICH ENABLES MACHINE TO MIMIC HUMAN BEHAVIOUR
# MACHINE LEARNING : 3 TYPES -> 1)SUPERVISED 2)UNSUPERVISED 3)REINFORCEMENT
#
# SUPERVISED LEARNING -> LABELLED DATASET(INPUT + OUTPUT) , HELPER
# UNSUPERVISED LEARNING -> UNLABLLED DATASET(ONLY INPUT)
# REINFORCEMENT LEARNING -> NOTHING , (AGENT,ENVIRONEMNT,PENELTY,REWARD) BASED ON ACTIONS PERFORMED BY AGENT

# %% [raw]
# REGRESSION : 1)NUMERICAL DATA 2)CONTINUOUS DATA
# CLASSIFICATION : 1)CATEGORICAL DATA
#
# REGRESSION :
# LINEAR REGRESSION
# MULTIPLE REGRESSION
# SVR
# DTR
# RFR
# KNN REGRESSION
#
# CLASSIFICATION :
# LOGISTIC REGRESSION
# DTC
# SVC
# RFC
# KNN CLASSIFICATION
#
# UNSUPERVISED LEARNING :
# K MEANS CLUSTERING

# %% [raw]
# STEPS OF MACHINE LEARNING :
# 1)IMPORT ALL REQUIRED LIBRARIES LIKE NUMPY,PANDAS,MATPLOTLIB,SCIKIT-LEARN,TENSORFLOW,KERAS
# 2)IMPORT DATA USING PANDAS (pd.read_csv())
# 3)PERFORM EXPLORATORY DATA ANALYSIS OR PRE-PROCESSING (DATA CLEANING , ENCODING , TRANSFORMING , SCALING)
# NOW MAKE TARGET VARIABLES X , Y
# 4)DATA IS DIVIDED INTO TWO PARTS : 1)TRAINING DATA , 2) TESTING DATA (train_test_split(80,20)) <- sklearn function
# 5)IMPORT THE MACHINE LEARNING MODEL WHICH IS REQUIRED
# 6)FIT TRAINING DATA INTO THE MODEL
# 7)PREDICTIONS (.predict())
# 8)CHECK THE EVALUATION MATRIX (LIKE R2 SCORE , F1 SCORE , ACCURACY ETC...)
# 9)CONVERT MODEL INTO PKL FILE
# 10)MAKING GUI (FRONT-END)
# 11)PKL FILE IS ADJUSTED INTO THE GUI -> DEPLOYEMENT

# %% [raw]
# LINEAR REGRESSION :
# X -> input variable
# Y -> output variable
#
# random_state : fix training and testing data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("House Price Prediction Dataset.csv")
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
df = df.drop(["Id"], axis=1)

# %%
df.head()
# Out:
#    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage  \
# 0  1360         5          4       3       1970  Downtown  Excellent     No
# 1  4272         5          4       3       1958  Downtown  Excellent     No
# 2  3592         2          2       3       1938  Downtown       Good     No
# 3   966         4          2       2       1902  Suburban       Fair    Yes
# 4  4926         1          4       2       1975  Downtown       Fair    Yes
#
#     Price
# 0  149919
# 1  424998
# 2  266746
# 3  244020
# 4  636056

# %%
df.isnull().sum()
# Out:
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
df.shape
# Out:
# (2000, 9)

# %%
A = df[['Area']]
B = df['Price']

# %%
A_train , A_test , B_train, B_test = train_test_split(A , B , test_size = 0.2  , random_state = 42)

# %%
linearreg = LinearRegression()

# %%
linearreg.fit(A_train , B_train)
# Out:
# LinearRegression()

# %%
B_pred = linearreg.predict(A_test)

# %%
B_pred
# Out:
# array([536577.29535447, 535984.71121625, 536399.86944898, 536380.1963175 ,
#        536222.25968246, 536101.83069998, 536222.07582142, 536118.01047167,
#        536367.32604456, 535938.19437264, 536121.31997043, 536139.52221358,
#        535996.11060086, 536219.13404474, 536034.16983654, 536253.33219855,
#        535823.28122142, 536109.92058582, 536450.79895761, 536498.78668955,
#        536087.48953871, 536425.05841173, 535944.26178703, 535849.75721146,
#        536324.48642178, 535776.58051676, 536424.69068965, 536207.73466014,
#        536405.93686337, 536320.80920094, 535858.58254147, 536427.81632736,
#        536527.4690121 , 536235.86539956, 536174.82353363, 535933.23012451,
#        536381.48334479, 535782.64793115, 535949.22603516, 536130.14530044,
#        535994.63971252, 536316.94811906, 536137.68360316, 535973.12797061,
#        536367.5099056 , 536037.66319634, 536320.25761782, 536103.85317144,
# ...

# %%
A_test
# Out:
#       Area
# 1860   633
# 353   3856
# 1333  1598
# 905   1705
# 1289  2564
# ...    ...
# 965   1811
# 1284   794
# 1739  3540
# 261   3670
# 535   3519
#
# [400 rows x 1 columns]

# %%
B_test
# Out:
# 1860    514764
# 353     694256
# 1333     66375
# 905     650243
# 1289    223285
#          ...
# 965     386940
# 1284    632570
# 1739    494049
# 261     562193
# 535     447530
# Name: Price, Length: 400, dtype: int64

# %%
r2 = r2_score(B_test ,B_pred)

# %%
r2
# Out:
# -0.0007365003351658128

# %%
sns.regplot(x=B_test,y=B_pred,data=df)
# Out:
# <Axes: xlabel='Price'>
