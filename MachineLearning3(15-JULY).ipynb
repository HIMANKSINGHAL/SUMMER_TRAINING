# %% [raw]
# DECISION TREES :
# THERE ARE TWO TYPES -> ID3 AND CART
# IN ID3 -> INFORMATION GAIN SHOULD BE MAX AND USED IN DTC
# IN CART -> GINI INDEX SHOULD BE MIN AND USED IN DTC AND DTR

# %% [raw]
# PARAMETER TUNNING :-
# 1)MAX DEPTH OF THE DECISON TREE
# 2)PRUNNING > CUUTING OF TREE FROM WHERE THERE IS MAXIMUM ACCURACY IN THE TREE

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("House Price Prediction Dataset.csv")

# %%
df = df.head(10)
df
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
# 5   6  3944         1          2       1       1906     Urban       Poor
# 6   7  3671         1          1       2       1948     Rural       Poor
# 7   8  3419         2          4       1       1925  Suburban       Good
# 8   9   630         2          2       1       1932     Rural       Poor
# 9  10  2185         3          3       1       2000  Downtown       Poor
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056
# 5     No   93262
# 6    Yes  448722
# ...

# %%
df.isna().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
X = df[['Area', 'Bedrooms', 'Floors', 'Bathrooms']]
Y = df['Price']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred = dt.predict(X_test)

# %%
dt.score(X_train,Y_train)
# Out:
# 1.0

# %%
plt.figure(figsize=(24,10))
tree.plot_tree(
    dt,
    filled=True,
    feature_names=X.columns
)
plt.show()

# %%
import pickle
pickle.dump(dt, open("DTmodel1.pkl", "wb"))

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
cond = LabelEncoder()
df['Condition'] = cond.fit_transform(df['Condition'])
df
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage   Price
# 0   1  1360         5          4       3       1970  Downtown          0     No  149919
# 1   2  4272         5          4       3       1958  Downtown          0     No  424998
# 2   3  3592         2          2       3       1938  Downtown          2     No  266746
# 3   4   966         4          2       2       1902  Suburban          1    Yes  244020
# 4   5  4926         1          4       2       1975  Downtown          1    Yes  636056
# 5   6  3944         1          2       1       1906     Urban          3     No   93262
# 6   7  3671         1          1       2       1948     Rural          3    Yes  448722
# 7   8  3419         2          4       1       1925  Suburban          2    Yes  594893
# 8   9   630         2          2       1       1932     Rural          3    Yes  652878
# 9  10  2185         3          3       1       2000  Downtown          3     No  340375

# %%
A = df[['Area', 'Bedrooms', 'Floors', 'Bathrooms']]
B = df['Condition']

# %%
A_train,A_test,B_train,B_test = train_test_split(A,B,test_size=0.2,random_state=42)

# %%
dt1 = DecisionTreeClassifier()

# %%
dt1.fit(A_train,B_train)
# Out:
# DecisionTreeClassifier()

# %%
B_pred = dt1.predict(A_test)

# %%
dt1.score(A,B)
# Out:
# 0.9

# %%
plt.figure(figsize=(50,40))
tree.plot_tree(
    dt1,
    filled=True,
    feature_names=A.columns
)
plt.show()

# %%
import pickle
pickle.dump(dt1, open("DTmodel.pkl", "wb"))

# %%
#RANDOM FOREST :  <-ENSEMBLE LEARNING
# REGRESSION AND CLASSIFICATION

# %%
#HYPERPARAMETER TUNE
#GRIDSEARCH CV
