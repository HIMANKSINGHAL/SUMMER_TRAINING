# %%
#PYTHON LIBRARIES :
#1)NUMPY -> IT IS NUMERICAL PYTHON AND IN THE CODE WE WILL USE THE NUMPY AS NP (IS : IDENTITY OPERATOR)

# %%
a = 10
b = 10
a is b #CHECKS IF TWO VARIABLES POINT TO SAME LOCATION OR NOT
# Out:
# True

# %%
a = [1,2,3]
b = [2,3,1]
a is b
# Out:
# False

# %%
#(IN : MEMBERSHIP OPERATOR)
a = 5
b = [1,2,3,4,5]
print(a in b)
print(a not in b)
# Out:
# True
# False

# %%
#NUMPY LIBRARY :

# %% [raw]
# pip install numpy

# %%
import numpy as np

# %%
A = np.array([[1,2,3],[1,2,3]])
print(A)
# Out:
# [[1 2 3]
#  [1 2 3]]

# %%
A.shape
# Out:
# (2, 3)

# %%
A.size
# Out:
# 6

# %%
#ANONYMOUS FUNCTION :LAMBDA FUCNTION (LESS SPACE OR MORE SPACE ?)

# %%
#NUMPY IS USED FOR VIDEOS OR IMAGES WHEN MORE THEN 2D SIZE.

# %%
a = np.array([1,2,3])
b = np.array([2,3,4])
print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# [3 5 7]
# [-1 -1 -1]
# [0.5        0.66666667 0.75      ]
# [ 2  6 12]
# [1 2 3]
# [0 0 0]
# [ 1  8 81]

# %%
#TO REDUCE ARRAY SHAPE TO 1D
p = np.array([[1,2,3],[4,5,6]])
print(p)
print(p.flatten())
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
#MIN AND MAX ELEMENT OF ARRAY
a = np.array([1,2,3])
print(a.min())
print(a.max())
# Out:
# 1
# 3

# %%
from scipy.stats import mode

# %%
print(a.mean())
print(np.median(a))
print(stats.mode(a))
# Out:
# 2.0
# 2.0
# ModeResult(mode=np.int64(1), count=np.int64(1))

# %%
#dot product , transpose , inverse 
#MATRIX AND PROBABILITY AND STATISTICS

a = np.array([[1,2,3],[2,3,4]])
b = np.array([[2,3,1],[9,8,7]])
print(a.dot(b.T))
# Out:
# [[11 46]
#  [17 70]]
